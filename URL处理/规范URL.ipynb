# %%
import pandas as pd 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 创建Chrome WebDriver实例并设置为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")  # 启用无头模式
chrome_options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36")
driver = webdriver.Chrome(options=chrome_options)  # 请确保已经安装了Chrome WebDriver，并提供正确的路径


def deal_url(url,path):
    df0 = pd.read_excel(path)
    for i, row in df0.iterrows():
        # 打开第一个URL
        driver.get(row[url])
        # 获取第一个URL导致的页面的源代码
        new_url = driver.current_url
        df0.at[i, url] = new_url
    return df0

import os

current_directory = os.getcwd()
for filepath,_,filenames in os.walk(current_directory):
    for filename in filenames:
        path = os.path.join(filepath,filename)
        URL0 = filename.split('.')[0]
        index0 = filename.split('.')[1]
        format0 = filename.split('.')[-1]
        if format0 == 'xlsx':
            df1 = deal_url(URL0,path)
            df1.to_excel(URL0 + index0 + '_new.xlsx',index=False)

# 关闭WebDriver
driver.quit()

# %%
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options
import os
import concurrent.futures

# 创建Chrome WebDriver实例并设置为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")
chrome_options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36")
driver = webdriver.Chrome(options=chrome_options)

# 收集要处理的URL列表
url_list = []
current_directory = os.getcwd()
for filepath, _, filenames in os.walk(current_directory):
    for filename in filenames:
        path = os.path.join(filepath, filename)
        format0 = filename.split('.')[-1]
        if format0 == 'xlsx':
            URL0 = filename.split('_')[0]
            df0 = pd.read_excel(path)
            for _, row in df0.iterrows():
                url_list.append(row[URL0])

# 处理URL的函数
def process_url(url):
    driver.get(url)
    new_url = driver.current_url
    return new_url

# 使用多线程并行处理URL
with concurrent.futures.ThreadPoolExecutor(max_workers=4) as executor:
    new_urls = list(executor.map(process_url, url_list))

# 将新的URL更新到DataFrame中
index = 0
for filepath, _, filenames in os.walk(current_directory):
    for filename in filenames:
        path = os.path.join(filepath, filename)
        format0 = filename.split('.')[-1]
        if format0 == 'xlsx':
            URL0 = filename.split('_')[0]
            df0 = pd.read_excel(path)
            df0[URL0] = new_urls[index:index+len(df0)]
            df0.to_excel(URL0 + index + '_new.xlsx', index=False)
            index += len(df0)

# 关闭WebDriver
driver.quit()
# Out:
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# Cell In[1], line 34
#      32 # 使用多线程并行处理URL
#      33 with concurrent.futures.ThreadPoolExecutor(max_workers=6) as executor:
# ---> 34     new_urls = list(executor.map(process_url, url_list))
#      36 # 将新的URL更新到DataFrame中
#      37 index = 0
#
# File d:\App\Anaconda\Lib\concurrent\futures\_base.py:619, in Executor.map.<locals>.result_iterator()
#     616 while fs:
#     617     # Careful not to keep a reference to the popped future
#     618     if timeout is None:
# --> 619         yield _result_or_cancel(fs.pop())
#     620     else:
#     621         yield _result_or_cancel(fs.pop(), end_time - time.monotonic())
#
# File d:\App\Anaconda\Lib\concurrent\futures\_base.py:317, in _result_or_cancel(***failed resolving arguments***)
#     315 try:
#     316     try:
# --> 317         return fut.result(timeout)
#     318     finally:
#     319         fut.cancel()
#
# File d:\App\Anaconda\Lib\concurrent\futures\_base.py:456, in Future.result(self, timeout)
#     454     raise CancelledError()
#     455 elif self._state == FINISHED:
# --> 456     return self.__get_result()
#     457 else:
#     458     raise TimeoutError()
#
# File d:\App\Anaconda\Lib\concurrent\futures\_base.py:401, in Future.__get_result(self)
#     399 if self._exception:
#     400     try:
# --> 401         raise self._exception
#     402     finally:
#     403         # Break a reference cycle with the exception in self._exception
#     404         self = None
#
# File d:\App\Anaconda\Lib\concurrent\futures\thread.py:58, in _WorkItem.run(self)
#      55     return
#      57 try:
# ---> 58     result = self.fn(*self.args, **self.kwargs)
#      59 except BaseException as exc:
#      60     self.future.set_exception(exc)
#
# Cell In[1], line 28, in process_url(url)
#      27 def process_url(url):
# ---> 28     driver.get(url)
#      29     new_url = driver.current_url
#      30     return new_url
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:353, in WebDriver.get(self, url)
#     351 def get(self, url: str) -> None:
#     352     """Loads a web page in the current browser session."""
# --> 353     self.execute(Command.GET, {"url": url})
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\webdriver.py:344, in WebDriver.execute(self, driver_command, params)
#     342 response = self.command_executor.execute(driver_command, params)
#     343 if response:
# --> 344     self.error_handler.check_response(response)
#     345     response["value"] = self._unwrap_value(response.get("value", None))
#     346     return response
#
# File ~\AppData\Roaming\Python\Python311\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# WebDriverException: Message: unknown error: net::ERR_CONNECTION_TIMED_OUT
#   (Session info: headless chrome=116.0.5845.180)
# Stacktrace:
# 	GetHandleVerifier [0x00007FF704EB52A2+57122]
# 	(No symbol) [0x00007FF704E2EA92]
# 	(No symbol) [0x00007FF704CFE3AB]
# 	(No symbol) [0x00007FF704CFA161]
# 	(No symbol) [0x00007FF704CECADF]
# 	(No symbol) [0x00007FF704CEDE82]
# 	(No symbol) [0x00007FF704CECEB8]
# 	(No symbol) [0x00007FF704CEBFBE]
# 	(No symbol) [0x00007FF704CEBF63]
# 	(No symbol) [0x00007FF704CEA9E5]
# 	(No symbol) [0x00007FF704CEB153]
# 	(No symbol) [0x00007FF704CFFF4B]
# 	(No symbol) [0x00007FF704D6EEF7]
# 	(No symbol) [0x00007FF704D56FDA]
# 	(No symbol) [0x00007FF704D6EB82]
# 	(No symbol) [0x00007FF704D56DB3]
# 	(No symbol) [0x00007FF704D2D2B1]
# 	(No symbol) [0x00007FF704D2E494]
# 	GetHandleVerifier [0x00007FF70515EF82+2849794]
# 	GetHandleVerifier [0x00007FF7051B1D24+3189156]
# 	GetHandleVerifier [0x00007FF7051AACAF+3160367]
# 	GetHandleVerifier [0x00007FF704F46D06+653702]
# 	(No symbol) [0x00007FF704E3A208]
# 	(No symbol) [0x00007FF704E362C4]
# 	(No symbol) [0x00007FF704E363F6]
# 	(No symbol) [0x00007FF704E267A3]
# 	BaseThreadInitThunk [0x00007FFCC62726AD+29]
# 	RtlUserThreadStart [0x00007FFCC714AA78+40]

# %%
import os
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 创建Chrome WebDriver实例并设置为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")  # 启用无头模式
driver = webdriver.Chrome(options=chrome_options)  # 请确保已经安装了Chrome WebDriver，并提供正确的路径

def deal_url(url, path, driver):
    df0 = pd.read_excel(path)
    for i, row in df0.iterrows():
        # 打开URL
        driver.get(row[url])
        # 获取导致的新URL
        new_url = driver.current_url
        df0.at[i, url] = new_url
    return df0

current_directory = os.getcwd()
for filepath, _, filenames in os.walk(current_directory):
    for filename in filenames:
        path = os.path.join(filepath, filename)
        URL0 = filename.split('.')[0]
        index0 = filename.split('.')[1]
        format0 = filename.split('.')[-1]
        if format0 == 'xlsx':
            df1 = deal_url(URL0, path, driver)
            df1.to_excel(f'{URL0}_{index0}_new.xlsx', index=False)

# 处理完所有URL后关闭WebDriver
driver.quit()

# %%
import pandas as pd 
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 创建Chrome WebDriver实例并设置为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")  # 启用无头模式
chrome_options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/90.0.4430.85 Safari/537.36")
driver = webdriver.Chrome(options=chrome_options)  # 请确保已经安装了Chrome WebDriver，并提供正确的路径

import os

current_directory = os.getcwd()
for filepath,_,filenames in os.walk(current_directory):
    for filename in filenames:
        path = os.path.join(filepath,filename)
        URL0 = filename.split('.')[0]
        index0 = filename.split('.')[1]
        format0 = filename.split('.')[-1]
        if format0 == 'xlsx':
            df0 = pd.read_excel(path)
            for i, row in df0.iterrows():
                # 打开第一个URL
                driver.get(row[URL0])
                # 获取第一个URL导致的页面的源代码
                new_url = driver.current_url
                df0.at[i, URL0] = new_url
            df0.to_excel(URL0 + index0 + '_new.xlsx',index=False)

# 关闭WebDriver
driver.quit()
# Out:
# 'c:\\Users\\WYJ20\\OneDrive\\桌面\\wenge实习\\渠道\\规范URL'

# %%
import pandas as pd
df0 = pd.read_excel(r"C:\Users\WYJ20\OneDrive\桌面\wenge实习\渠道\规范URL\URL.1.xlsx")
# array0 = df0[:]["URL"]

import os
import pandas as pd
from selenium import webdriver
from selenium.webdriver.chrome.options import Options

# 创建Chrome WebDriver实例并设置为无头模式
chrome_options = Options()
chrome_options.add_argument("--headless")  # 启用无头模式
driver = webdriver.Chrome(options=chrome_options)  # 请确保已经安装了Chrome WebDriver，并提供正确的路径

# driver.get(array0[3])
#         # 获取导致的新URL
# new_url = driver.current_url
# new_url
for i, row in df0.iterrows():
        # 打开URL
        driver.get(row["URL"])
        # 获取导致的新URL
        new_url = driver.current_url
        df0.at[i, "URL"] = new_url

driver.quit()
df0.head()
# Out:
#     序号                                           标题                 发布时间 倾向性  \
# 0  104                        私自投喂！2名游客被终身禁入成都大熊猫基地  2023-08-27 21:54:59  中性
# 1  122  请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫  #成都大熊猫基地  #私自投喂  2023-08-27 21:53:55  负面
# 2  126                                      多么可爱的国宝  2023-08-27 21:53:41  中性
# 3  127    请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫 #成都大熊猫基地 #私自投喂  2023-08-27 21:53:39  负面
# 4  128    请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫 #成都大熊猫基地 #私自投喂  2023-08-27 21:53:39  负面
#
#      来源网站       作者         作者id 信息发布地域 媒体类型 文章类型  信源范围   阅读数  评论/回复数  转发数  \
# 0  新浪微博视频  SMGNEWS   1925878362    NaN  短视频   原发  其他媒体   921       0    0
# 1      快手  河北广播电视台   1551546944     河北  短视频   原发  省级媒体   323       0    0
# 2  新浪微博视频   秋灵林511   7824207170     浙江  短视频   原发  其他媒体     0       0    0
# 3      抖音  河北广播电视台  98453571550     河北  短视频   原发  其他媒体     0       0    0
# 4    西瓜视频  河北广播电视台   3744343345     河北  短视频   原发  其他媒体  6292       1    0
#
#    点赞数      粉丝量                                                URL  \
# 0    2   346006  https://passport.weibo.com/visitor/visitor?ent...
# 1    4  4270275  https://www.kuaishou.com/short-video/3xj22ux48...
# 2    0    11375  https://passport.weibo.com/visitor/visitor?ent...
# 3    0  8221888   https://www.douyin.com/video/7271999699190549812
# 4   44  8220378        https://www.ixigua.com/7271999699190549812/
#
#                                                   摘要  关键词
# 0  【私自投喂！#2游客被终生禁入成都大熊猫基地#】8月26日，成都大熊猫繁育研究基地内，有网友...  NaN
# 1        请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫  #成都大熊猫基地  #私自投喂  NaN
# 2                       #2游客被终生禁入成都大熊猫基地#多么可爱的国宝[爱你]  NaN
# 3          请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫 #成都大熊猫基地 #私自投喂  NaN
# 4          请勿私自投喂！两游客被终生禁入成都大熊猫基地 #熊猫 #成都大熊猫基地 #私自投喂  NaN

# %%
# Out:
# ---------------------------------------------------------------------------
# Terminator                                Traceback (most recent call last)
# Cell In[4], line 13
#      11     turtle.pendown()
#      12     turtle.forward(16 * pow(Math.sin(i / 50 * Math.pi), 3))
# ---> 13     turtle.left(120)
#      14     turtle.color('red')
#      16 # 画右半边心形
#
# File <string>:8, in left(angle)
#
# File d:\App\Anaconda\Lib\turtle.py:1700, in TNavigator.left(self, angle)
#    1681 def left(self, angle):
#    1682     """Turn turtle left by angle units.
#    1683
#    1684     Aliases: left | lt
#    (...)
#    1698     67.0
#    1699     """
# -> 1700     self._rotate(angle)
#
# File d:\App\Anaconda\Lib\turtle.py:3293, in RawTurtle._rotate(self, angle)
#    3291     for _ in range(steps):
#    3292         self._orient = self._orient.rotate(delta)
# -> 3293         self._update()
#    3294 self._orient = neworient
#    3295 self._update()
#
# File d:\App\Anaconda\Lib\turtle.py:2661, in RawTurtle._update(self)
#    2659     return
#    2660 elif screen._tracing == 1:
# -> 2661     self._update_data()
#    2662     self._drawturtle()
#    2663     screen._update()                  # TurtleScreenBase
#
# File d:\App\Anaconda\Lib\turtle.py:2647, in RawTurtle._update_data(self)
#    2646 def _update_data(self):
# -> 2647     self.screen._incrementudc()
#    2648     if self.screen._updatecounter != 0:
#    2649         return
#
# File d:\App\Anaconda\Lib\turtle.py:1293, in TurtleScreen._incrementudc(self)
#    1291 if not TurtleScreen._RUNNING:
#    1292     TurtleScreen._RUNNING = True
# -> 1293     raise Terminator
#    1294 if self._tracing > 0:
#    1295     self._updatecounter += 1
#
# Terminator:
